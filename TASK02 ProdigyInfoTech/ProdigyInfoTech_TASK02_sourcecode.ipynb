# %% [markdown]
# # <br/><br/>
# <center><a style="font-size: 36pt; color: black ; font-weight: bold">ProdigyInfoTech Summer Internship 2024</a></center>
# <br/><br/>

# %% [markdown]
# TASK#2:
# Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %%
#1) Analyze the dataset abd check total columns and rows.

import pandas as pd

df = pd.read_csv("gender_submission.csv")

print("The dataset is as follows: ")
df
# Out:
# The dataset is as follows:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
# Check for missing values and data types

print("Data Types:\n", df.dtypes)

print("\nMissing Values:\n", df.isnull().sum())

# According to the output "There is no any missing value in Dataset".

# If there is any missing value exists in PassengerId or survived column
# We can filled it all by mean/average of relevent column

# df['PassengerId'].fillna(df['PassengerId'].mean(), inplace=True)
# df['Survived'].fillna(df['Survived'].mean(), inplace=True)
# Out:
# Data Types:
#  PassengerId    int64
# Survived       int64
# dtype: object
#
# Missing Values:
#  PassengerId    0
# Survived       0
# dtype: int64

# %% [markdown]
# # Visualize and Explore the data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of survival rates
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Survived')
plt.title('Distribution of Survival Rates')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# Analyzing trends based on PassengerId
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='PassengerId', y='Survived', hue='Survived', palette='viridis', s=100)
plt.title('Survival by PassengerId')
plt.xlabel('PassengerId')
plt.ylabel('Survived')
plt.show()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Distribution of survival rates
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Survived')
plt.title('Distribution of Survival Rates')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
# Analyzing trends based on PassengerId
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='PassengerId', y='Survived', hue='Survived', palette='viridis', s=100)
plt.title('Survival by PassengerId')
plt.xlabel('PassengerId')
plt.ylabel('Survived')
plt.show()

# %%
# Summary statistics for Survived
summary_stats = df['Survived'].describe()

# Grouping by Survived and counting the number of passengers
grouped_stats = df.groupby('Survived')['PassengerId'].count().reset_index(name='PassengerCount')

sorted_by_passenger_id, sorted_by_survived, summary_stats, grouped_stats
# Out:
# (     PassengerId  Survived
#  0            892         0
#  1            893         1
#  2            894         0
#  3            895         0
#  4            896         1
#  ..           ...       ...
#  413         1305         0
#  414         1306         1
#  415         1307         0
#  416         1308         0
#  417         1309         0
#
#  [418 rows x 2 columns],
#       PassengerId  Survived
#  0            892         0
#  256         1148         0
#  255         1147         0
#  254         1146         0
#  253         1145         0
#  ..           ...       ...
#  275         1167         1
#  92           984         1
#  90           982         1
#  263         1155         1
#  208         1100         1
#
#  [418 rows x 2 columns],
#  count    418.000000
#  mean       0.363636
#  std        0.481622
#  min        0.000000
#  25%        0.000000
#  50%        0.000000
#  75%        1.000000
#  max        1.000000
#  Name: Survived, dtype: float64,
# ...

# %%
# Replace 0 with "No" and 1 with "Yes" to better understanding

df['Survived'] = df['Survived'].replace({0: 'No', 1: 'Yes'})

df
# Out:
#      PassengerId Survived
# 0            892       No
# 1            893      Yes
# 2            894       No
# 3            895       No
# 4            896      Yes
# ..           ...      ...
# 413         1305       No
# 414         1306      Yes
# 415         1307       No
# 416         1308       No
# 417         1309       No
#
# [418 rows x 2 columns]
