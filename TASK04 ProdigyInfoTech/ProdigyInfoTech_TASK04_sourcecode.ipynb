# %% [markdown]
# # <br/><br/>
# <center><a style="font-size: 36pt; color: black ; font-weight: bold">ProdigyInfoTech Summer Internship 2024</a></center>
# <br/><br/>

# %% [markdown]
# TASK#4:
# Analyze and visualize sentiment patterns in social media data to understand public opinion and attitudes towards specific topics or brands.

# %%
#1) Analyze the dataset abd check total columns and rows.

import pandas as pd

df = pd.read_csv("twitter_validation.csv")

print("The dataset is as follows: ")
df
# Out:
# The dataset is as follows:
#      3364             Facebook  Irrelevant  \
# 0     352               Amazon     Neutral
# 1    8312            Microsoft    Negative
# 2    4371                CS-GO    Negative
# 3    4433               Google     Neutral
# 4    6273                 FIFA    Negative
# ..    ...                  ...         ...
# 994  4891  GrandTheftAuto(GTA)  Irrelevant
# 995  4359                CS-GO  Irrelevant
# 996  2652          Borderlands    Positive
# 997  8069            Microsoft    Positive
# 998  6960      johnson&johnson     Neutral
#
#     I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
# 0    BBC News - Amazon boss Jeff Bezos rejects clai...
# 1    @Microsoft Why do I pay for WORD when it funct...
# 2    CSGO matchmaking is so full of closet hacking,...
# ...

# %%
# Analyze and visualize sentiment patterns in the provided social media dataset

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate sentiment distribution for each brand
counts = df.groupby(['Facebook', 'Irrelevant']).size().unstack(fill_value=0)

# Display sentiment counts
counts
# Out:
# Irrelevant                         Irrelevant  Negative  Neutral  Positive
# Facebook
# Amazon                                      3         6       18         7
# ApexLegends                                 3         6       17        10
# AssassinsCreed                              1         4        4        24
# Battlefield                                12         7        4         3
# Borderlands                                 2         5       12        14
# CS-GO                                       8         2       13         9
# CallOfDuty                                 11         8        7         5
# CallOfDutyBlackopsColdWar                   8         3        6        10
# Cyberpunk2077                               8         1        4        17
# Dota2                                       1         8       11         7
# FIFA                                       10        16        4         8
# ...

# %%
# Visualization

# Plotting sentiment distribution across brands
plt.figure(figsize=(12,6))
sentiment_counts.plot(kind="bar", stacked=True)
plt.title("Sentiment Distribution Across Brands")
plt.xlabel("Facebook (Social Media Brands)")
plt.ylabel("Counts")
plt.legend(title="Sentiment Distribution Across All Brands")
plt.xticks(rotation=90)
plt.show()

# %%
overall_counts = df["Irrelevant"].value_counts()

# Plotting the overall sentiment distribution
plt.figure(figsize=(8, 8))
overall_counts.plot(kind="pie", autopct="%1.1f%%", startangle=70)
plt.title("Overall Sentiment Distribution")
plt.ylabel('Overall Counts')
plt.show()
